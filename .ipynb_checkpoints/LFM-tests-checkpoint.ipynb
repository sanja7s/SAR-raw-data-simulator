# %% [markdown]
# ## SAR raw data simulator
#
# based on the book Digital signal processing techniques and applications in radar image processing book by Bu-Chin Wang.
#
#
# The M x N array of 2D radar image raw data is formed by M bursts of radar pulses with N samples each. The purpose of SAR processing, ideally, is to convert the raw data into a single pixel in the final processed image.

# %%
import sys
sys.version
sys.version_info
# Out:
# sys.version_info(major=3, minor=5, micro=2, releaselevel='final', serial=0)

# %%
import numpy as np
import math
from collections import defaultdict
import matplotlib.pyplot as plt
import matplotlib.pylab as pylab
# %matplotlib inline
pylab.rcParams['figure.figsize'] = 12, 8  # that's default image size for this interactive session

# %% [markdown]
# We will focus only on airborne-based radar image data processing; therefore, the
# estimation of Doppler centroid and Doppler frequency ambiguity, which is critical
# for satellite-based squint SAR systems, is not addressed here.
#
# We need some information about the radar system:
#
# h -- altitude of the flying vehicle (satellite or plane)
#
# v -- the speed of the vehicle
#
# PRI -- pulse repetition interval
#
# PRF -- pulse repetition frequency = 1 / PRI
#
# time7s -- how long we fly and send the set of pulses
#
# lambd -- our carrier signal frequency = 0.0311 in the case of X-band and 9.65GHz

# %% [markdown]
# # LFM pulsed signal #
#
# At Iceye, we work with a pulsed LFM (linear frequency modulation) waveform.
#
# A0 = 1 amplititude of the transimtter signal
#
# Tp -- pulse duration
#
# fc -- carrier frequency
#
# alpha7s -- LFM pulse chirp rate (range FM rate α = 4e12 Hz/s in the example from the book)

# %%
# radar beam carrier frequency (Hz)
fc = 1.0e10 
# light speed (speed of wave) (m/s)
c = 3.0e8
# wavelength of carrier = c/fc (m)
lambd = c / fc
# amplitude of transimtter signal
A0 = 1.0
# time for how long we observe one pulse
time7s = 250
# pulse repetition frequency (Hz                                 )
PRF = 500
# pulse duration (s)
Tp = 6.033e-6
# total pulses 
tot_pulses = PRF * time7s
# LFM pulse chirp rate (Range FM rate) (Hz/s)
alpha7s = 4.0e12
# number of time samples total
tot_samples = 250
# number of time samples within the LFM pulse (fs*Tp)
signal_samples = 181

# %%
def plot_LFM_pulses(p, type7s = 'nonsymmetric'):
    x = range(0, len(p))
    print (len(x))
    y1 = p.real
    y2 = p.imag
    # Two subplots, the axes array is 1-d
    f, axarr = plt.subplots(2, sharex=True)
    axarr[0].plot(x, y1)
    axarr[0].set_title('LFM pulse real part ' + type7s)
    axarr[1].set_title('LFM pulse imaginary part ' + type7s)
    axarr[1].plot(x, y2)
    axarr[1].set_xlabel('time samples')
    axarr[0].set_ylabel('amplitude')
    axarr[1].set_ylabel('amplitude')

# %%
def generateNonsymmetricPulsedLFM(A0, Tp, fc, alpha7s, tot_samples, signal_samples):
    t = np.linspace(0, Tp*(tot_samples/signal_samples), tot_samples, endpoint=False)
    mask = abs((t-Tp/2)/Tp)<=0.5
    mask = mask.astype(int)
    p = (A0*np.exp(1j*2*np.pi*fc*t + 1j*np.pi*alpha7s*t*t)) * mask
    return p

# %%
p = generateNonsymmetricPulsedLFM(A0, Tp, fc, alpha7s, tot_samples)
plot_LFM_pulses(p)
# Out:
# 250

# %%
def generateSymmetricPulsedLFM(A0, Tp, fc, alpha7s, tot_samples):
    t = np.linspace(0, Tp*(tot_samples/signal_samples), tot_samples, endpoint=False)
    mask = abs((t-Tp/2)/Tp)<=0.5
    mask = mask.astype(int)
    p = (A0*np.exp(1j*2*np.pi*fc*(t-Tp/2) + 1j*np.pi*alpha7s*(t-Tp/2)*(t-Tp/2))) * mask
    return p

# %%
ps = generateSymmetricPulsedLFM(A0=1, Tp=4e-6, fc=fc, alpha7s=2e12, tot_samples=250, signal_samples=81)
plot_LFM_pulses(ps, type7s='symmetric')
# Out:
# 250

# %% [markdown]
# # Point-target simulation

# %%
# closest rnge of the target R0 (m)
R0 = 7500
# range sampling frequency fs (Hz)
fs = 30.0e6
# range bandwidth B = alpha * Tp (Hz)
B = 24.13e6
# radar moving speed (m/s)
V = 200
# azimuth FM rate = -2V*V/(R0*lambda) (Hz/s)
AFMrate = -355.56
# antenna length (m)
L = 1.0

# %% [markdown]
# The following parameters we can calculate from tose already given

# %%
# slant range sample spacing Rs = c/fs (m)
Rs = c / fs
# Radar 3-db beamwidth thetaH = lambda / L (radians)
thetaH = 0.03
# azimuth sample spacing As = V/PRF (m)
As = V/PRF
# synthetic apreture lentgh Ls = R0 thetaH (m)
Ls = R0 * thetaH
# Doppler frequency bandwidth Bdop = 2V/L (Hz)
Bdop = 400
# number of azimuth samples 
Naz = int(Ls/As)
# number of time samples within LFM pulse 
Nr = fs * Tp
# number of time samples 
Ntot = 181
# stant range R1 = R3 = R0/cos(0.5*thetaH)
R1 = R3 = R0/math.cos(0.5*thetaH)

# %% [markdown]
# The slant range difference, namely, R 1 − R 0 = 7500.8 − 7500 = 0.8 m, is less than
# 1/ 4 of the range resolution, which is (c/2B)/4 = 1.56 m in this setup. Therefore, range
# migration correction is not needed in this broadside SAR case.

# %%
def point_target_simulation(point_target_img):
    all_pulses = defaultdict(list)
    for i in range(tot_pulses):
        all_pulses[i] = generateIdealChirp(30,90,1000,75)
    return all_pulses
